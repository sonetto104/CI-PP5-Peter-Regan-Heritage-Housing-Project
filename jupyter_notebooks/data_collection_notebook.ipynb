# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save it as raw data.
# * Inspect data and save it under outputs/datasets/collection.
# * Assess the need for data cleaning based on inital inspection.
#
# ## Inputs
#
# * Kaggle JSON file - this is the authentication token required to access the Kaggle dataset.
#
# ## Outputs
#
# * Generate dataset: outputs/datasets/collection/house_prices_records.csv

# %% [markdown]
# ## Kernel Selection
#
# Please use a Python 3.8.12 kernel to run this notebook. This application has been developed in a local workspace using Python 3.8.12. If you use a different version of Python to run this notebook, some of the required dependencies may not function correctly.

# %% [markdown]
# ---

# %% [markdown]
# ## Install Python Packages in the Notebooks

# %%
# %pip install -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt
# Out:
# Collecting altair==4.2.2
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# Collecting astor==0.8.1
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: asttokens==2.2.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 3)) (2.2.1)
# Collecting attrs==23.1.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Requirement already satisfied: backcall==0.2.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 5)) (0.2.0)
# Collecting backports.zoneinfo==0.2.1
#   Using cached backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
# Collecting base58==2.1.1
#   Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting blinker==1.6.2
#   Using cached blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting cachetools==5.3.1
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting certifi==2023.7.22
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Collecting charset-normalizer==3.2.0
#   Using cached charset_normalizer-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
# Collecting click==7.1.2
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: comm==0.1.4 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 13)) (0.1.4)
# Collecting cycler==0.11.0
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting dacite==1.8.1
#   Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: debugpy==1.6.7.post1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 16)) (1.6.7.post1)
# Requirement already satisfied: decorator==5.1.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 17)) (5.1.1)
# Collecting entrypoints==0.4
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: executing==1.2.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 19)) (1.2.0)
# Collecting feature-engine==1.0.2
#   Using cached feature_engine-1.0.2-py2.py3-none-any.whl (152 kB)
# Collecting gitdb==4.0.10
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting GitPython==3.1.32
#   Using cached GitPython-3.1.32-py3-none-any.whl (188 kB)
# Collecting htmlmin==0.1.12
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
# Collecting idna==3.4
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting ImageHash==4.3.1
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Collecting imbalanced-learn==0.8.0
#   Using cached imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
# Requirement already satisfied: importlib-metadata==6.8.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 27)) (6.8.0)
# Collecting importlib-resources==6.0.1
#   Using cached importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: ipykernel==6.25.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 29)) (6.25.1)
# Requirement already satisfied: ipython==8.12.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 30)) (8.12.2)
# Collecting ipywidgets==8.0.2
#   Using cached ipywidgets-8.0.2-py3-none-any.whl (134 kB)
# Requirement already satisfied: jedi==0.19.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 32)) (0.19.0)
# Collecting Jinja2==3.1.1
#   Using cached Jinja2-3.1.1-py3-none-any.whl (132 kB)
# Collecting joblib==1.3.2
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting jsonschema==4.19.0
#   Using cached jsonschema-4.19.0-py3-none-any.whl (83 kB)
# Collecting jsonschema-specifications==2023.7.1
#   Using cached jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: jupyter-client==8.3.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 37)) (8.3.0)
# Requirement already satisfied: jupyter-core==5.3.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 38)) (5.3.1)
# Collecting jupyterlab-widgets==3.0.8
#   Using cached jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
# Collecting kiwisolver==1.4.4
#   Using cached kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Collecting MarkupSafe==2.0.1
#   Using cached MarkupSafe-2.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting matplotlib==3.3.1
#   Using cached matplotlib-3.3.1-cp38-cp38-manylinux1_x86_64.whl (11.6 MB)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 43)) (0.1.6)
# Collecting multimethod==1.9.1
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: nest-asyncio==1.5.7 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 45)) (1.5.7)
# Collecting networkx==3.1
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting numpy==1.18.5
#   Using cached numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# Requirement already satisfied: packaging==23.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 48)) (23.1)
# Collecting pandas==1.4.2
#   Using cached pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Requirement already satisfied: parso==0.8.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 50)) (0.8.3)
# Collecting patsy==0.5.3
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pexpect==4.8.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 52)) (4.8.0)
# Collecting phik==0.12.3
#   Using cached phik-0.12.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 54)) (0.7.5)
# Collecting Pillow==10.0.0
#   Using cached Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting pkgutil-resolve-name==1.3.10
#   Using cached pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: platformdirs==3.10.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 57)) (3.10.0)
# Collecting plotly==4.12.0
#   Using cached plotly-4.12.0-py2.py3-none-any.whl (13.1 MB)
# Collecting ppscore==1.2.0
#   Using cached ppscore-1.2.0.tar.gz (47 kB)
# Requirement already satisfied: prompt-toolkit==3.0.39 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 60)) (3.0.39)
# Collecting protobuf==3.20.0
#   Using cached protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: psutil==5.9.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 62)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 63)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 64)) (0.2.2)
# Collecting pyarrow==12.0.1
#   Using cached pyarrow-12.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.0 MB)
# Collecting pydantic==1.10.12
#   Using cached pydantic-1.10.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting pydeck==0.8.1b0
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Requirement already satisfied: Pygments==2.16.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 68)) (2.16.1)
# Collecting pyparsing==3.1.1
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 70)) (2.8.2)
# Collecting pytz==2023.3
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting PyWavelets==1.4.1
#   Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Collecting PyYAML==6.0.1
#   Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
# Requirement already satisfied: pyzmq==25.1.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 74)) (25.1.1)
# Collecting referencing==0.30.2
#   Using cached referencing-0.30.2-py3-none-any.whl (25 kB)
# Collecting requests==2.31.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting retrying==1.3.4
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting rpds-py==0.9.2
#   Using cached rpds_py-0.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting scikit-learn==0.24.2
#   Using cached scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# Collecting scipy==1.9.3
#   Using cached scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# Collecting seaborn==0.11.0
#   Using cached seaborn-0.11.0-py3-none-any.whl (283 kB)
# Requirement already satisfied: six==1.16.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 82)) (1.16.0)
# Collecting smmap==5.0.0
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: stack-data==0.6.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 84)) (0.6.2)
# Collecting statsmodels==0.14.0
#   Using cached statsmodels-0.14.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Collecting streamlit==0.85.0
#   Using cached streamlit-0.85.0-py2.py3-none-any.whl (7.9 MB)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting threadpoolctl==3.2.0
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting toml==0.10.2
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting toolz==0.12.0
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: tornado==6.3.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 91)) (6.3.3)
# Collecting tqdm==4.66.1
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: traitlets==5.9.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 93)) (5.9.0)
# Collecting typeguard==2.13.3
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions==4.7.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 95)) (4.7.1)
# Collecting tzlocal==5.0.1
#   Using cached tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Collecting urllib3==2.0.4
#   Using cached urllib3-2.0.4-py3-none-any.whl (123 kB)
# Collecting validators==0.21.2
#   Using cached validators-0.21.2-py3-none-any.whl (25 kB)
# Collecting visions==0.7.5
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# Collecting watchdog==3.0.0
#   Using cached watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
# Requirement already satisfied: wcwidth==0.2.6 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 101)) (0.2.6)
# Collecting widgetsnbextension==4.0.8
#   Using cached widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
# Collecting wordcloud==1.9.2
#   Using cached wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Collecting xgboost==1.2.1
#   Using cached xgboost-1.2.1-py3-none-manylinux2010_x86_64.whl (148.9 MB)
# Collecting ydata-profiling==4.4.0
#   Using cached ydata_profiling-4.4.0-py2.py3-none-any.whl (356 kB)
# Collecting yellowbrick==1.3
#   Using cached yellowbrick-1.3-py3-none-any.whl (271 kB)
# Requirement already satisfied: zipp==3.16.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 107)) (3.16.2)
# Using legacy 'setup.py install' for htmlmin, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for ppscore, since package 'wheel' is not installed.
# Installing collected packages: rpds-py, attrs, referencing, pytz, numpy, importlib-resources, tangled-up-in-unicode, smmap, scipy, PyWavelets, pyparsing, pkgutil-resolve-name, Pillow, pandas, networkx, multimethod, MarkupSafe, kiwisolver, jsonschema-specifications, cycler, certifi, visions, urllib3, toolz, threadpoolctl, patsy, matplotlib, jsonschema, joblib, Jinja2, ImageHash, idna, gitdb, entrypoints, charset-normalizer, backports.zoneinfo, wordcloud, widgetsnbextension, watchdog, validators, tzlocal, typeguard, tqdm, toml, statsmodels, seaborn, scikit-learn, retrying, requests, PyYAML, pydeck, pydantic, pyarrow, protobuf, phik, jupyterlab-widgets, htmlmin, GitPython, dacite, click, cachetools, blinker, base58, astor, altair, yellowbrick, ydata-profiling, xgboost, streamlit, ppscore, plotly, ipywidgets, imbalanced-learn, feature-engine
#     Running setup.py install for htmlmin ... done
#     Running setup.py install for ppscore ... done
# Successfully installed GitPython-3.1.32 ImageHash-4.3.1 Jinja2-3.1.1 MarkupSafe-2.0.1 Pillow-10.0.0 PyWavelets-1.4.1 PyYAML-6.0.1 altair-4.2.2 astor-0.8.1 attrs-23.1.0 backports.zoneinfo-0.2.1 base58-2.1.1 blinker-1.6.2 cachetools-5.3.1 certifi-2023.7.22 charset-normalizer-3.2.0 click-7.1.2 cycler-0.11.0 dacite-1.8.1 entrypoints-0.4 feature-engine-1.0.2 gitdb-4.0.10 htmlmin-0.1.12 idna-3.4 imbalanced-learn-0.8.0 importlib-resources-6.0.1 ipywidgets-8.0.2 joblib-1.3.2 jsonschema-4.19.0 jsonschema-specifications-2023.7.1 jupyterlab-widgets-3.0.8 kiwisolver-1.4.4 matplotlib-3.3.1 multimethod-1.9.1 networkx-3.1 numpy-1.18.5 pandas-1.4.2 patsy-0.5.3 phik-0.12.3 pkgutil-resolve-name-1.3.10 plotly-4.12.0 ppscore-1.2.0 protobuf-3.20.0 pyarrow-12.0.1 pydantic-1.10.12 pydeck-0.8.1b0 pyparsing-3.1.1 pytz-2023.3 referencing-0.30.2 requests-2.31.0 retrying-1.3.4 rpds-py-0.9.2 scikit-learn-0.24.2 scipy-1.9.3 seaborn-0.11.0 smmap-5.0.0 statsmodels-0.14.0 streamlit-0.85.0 tangled-up-in-unicode-0.2.0 threadpoolctl-3.2.0 toml-0.10.2 toolz-0.12.0 tqdm-4.66.1 typeguard-2.13.3 tzlocal-5.0.1 urllib3-2.0.4 validators-0.21.2 visions-0.7.5 watchdog-3.0.0 widgetsnbextension-4.0.8 wordcloud-1.9.2 xgboost-1.2.1 ydata-profiling-4.4.0 yellowbrick-1.3
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project'

# %% [markdown]
# # Fetch Data from Kaggle

# %% [markdown]
# Install Kaggle package to collect data from Kaggle.

# %%
# %pip install kaggle==1.5.12
# Out:
# Collecting kaggle==1.5.12
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 2.3 MB/s eta 0:00:011
# Requirement already satisfied: six>=1.10 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (1.16.0)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2023.7.22)
# Requirement already satisfied: python-dateutil in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.8.2)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.31.0)
# Requirement already satisfied: tqdm in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (4.66.1)
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.0.4)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.3 MB/s eta 0:00:011
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests->kaggle==1.5.12) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests->kaggle==1.5.12) (3.4)
# Using legacy 'setup.py install' for kaggle, since package 'wheel' is not installed.
# Installing collected packages: text-unidecode, python-slugify, kaggle
#     Running setup.py install for kaggle ... done
# Successfully installed kaggle-1.5.12 python-slugify-8.0.1 text-unidecode-1.3
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You will need a Kaggle token to fetch the data required to run these notebooks. If you do not already have a Kaggle token, follow these steps:
#
# 1. Visit www.kaggle.com and register an account.
#
# 2. When you have finished registering your account, log in.
#
# 3. Click on your profile/account avatar that will be visible at the top right hand corner of the browser window.
#
# 4. Scroll down to the "API" section.
#
# 5. Click on "Create New Token". This will automatically create your kaggle token which will be in the form of a json
#    file.
#
# 6. Depending on your browser, this kaggle.json file should download automatically.
#
# 7. Download the kaggle.json file manually if this is not the case.

# %% [markdown]
# # Make Kaggle Token Available in Your Coding Environment
#
# Once your Kaggle token has been downloaded, you can manually click, hold and drag it from your Downloads folder on your device (or wherever else you may have chosen to store it) into the file directory of your coding environment.

# %% [markdown]
# After you have put your Kaggle token in your coding environment's file directory, run the cell below so that it is recognised within the session.

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %% [markdown]
# Get the dataset path from its Kaggle URL. For this application, use the dataset from this url: https://www.kaggle.com/datasets/codeinstitute/housing-prices-data

# %% [markdown]
# Run the following cell to define the Kaggle dataset within the context of your environment and session, set its destination folder and download it.

# %%
KaggleDatasetPath = "codeinstitute/housing-prices-data"
DestinationFolder = "inputs/datasets/raw"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# Downloading housing-prices-data.zip to inputs/datasets/raw
#   0%|                                               | 0.00/49.6k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 49.6k/49.6k [00:00<00:00, 2.13MB/s]

# %% [markdown]
# Run the following cell to unzip the downloaded file, delete the zip file and delete the kaggle.json file.

# %%
! unzip {DestinationFolder}/*.zip -d {DestinationFolder} \
  && rm {DestinationFolder}/*.zip \
  && rm kaggle.json
# Out:
# Archive:  inputs/datasets/raw/housing-prices-data.zip
#   inflating: inputs/datasets/raw/house-metadata.txt
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/inherited_houses.csv

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Kaggle Data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(f"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")
pd.set_option('display.max_columns', None)
df.head(40)
# Out:
#     1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0        856     854.0           3.0           No         706          GLQ
# 1       1262       0.0           3.0           Gd         978          ALQ
# 2        920     866.0           3.0           Mn         486          GLQ
# 3        961       NaN           NaN           No         216          ALQ
# 4       1145       NaN           4.0           Av         655          GLQ
# 5        796     566.0           1.0           No         732          GLQ
# 6       1694       0.0           3.0           Av        1369          GLQ
# 7       1107     983.0           3.0           Mn         859          ALQ
# 8       1022     752.0           2.0           No           0          Unf
# 9       1077       0.0           2.0           No         851          GLQ
# 10      1040       0.0           3.0           No         906          Rec
# 11      1182    1142.0           4.0           No         998          NaN
# 12       912       0.0           2.0           No         737          ALQ
# 13      1494       0.0           3.0           Av           0          Unf
# 14      1253       0.0           NaN           No         733          BLQ
# 15       854       0.0           2.0           No           0          Unf
# 16      1004       0.0           2.0           No         578          ALQ
# 17      1296       0.0           2.0         None           0         None
# 18      1114       NaN           NaN           No         646          GLQ
# 19      1339       0.0           3.0           No         504          LwQ
# 20      1158    1218.0           4.0           Av           0          Unf
# 21      1108       0.0           3.0           No           0          Unf
# 22      1795       0.0           3.0           No           0          NaN
# 23      1060       0.0           3.0           No         840          GLQ
# 24      1060       0.0           3.0           Mn         188          Rec
# 25      1600       0.0           3.0           No           0          Unf
# 26       900       0.0           3.0           Mn         234          NaN
# 27      1704       NaN           3.0           No        1218          GLQ
# 28      1600       0.0           2.0           Gd        1277          BLQ
# 29       520       0.0           1.0           No           0          Unf
# 30       649     668.0           3.0           No           0          Unf
# 31      1228       0.0           3.0           No           0          Unf
# 32      1234       0.0           3.0           Av           0          Unf
# 33      1700       0.0           4.0           No        1018          Rec
# 34      1561       0.0           2.0           No        1153          GLQ
# 35      1132    1320.0           4.0           Av           0          Unf
# 36      1097       0.0           3.0           No           0          Unf
# 37      1297       0.0           NaN           No        1213          Rec
# 38      1057       0.0           3.0           No         731          GLQ
# 39      1152       0.0           NaN         None           0         None
#
#     BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  GarageYrBlt  GrLivArea  \
# 0         150            0.0         548          RFn       2003.0       1710
# 1         284            NaN         460          RFn       1976.0       1262
# 2         434            0.0         608          RFn       2001.0       1786
# 3         540            NaN         642          Unf       1998.0       1717
# 4         490            0.0         836          RFn       2000.0       2198
# 5          64            NaN         480          Unf       1993.0       1362
# 6         317            NaN         636          RFn       2004.0       1694
# 7         216            NaN         484          NaN       1973.0       2090
# 8         952            NaN         468          Unf       1931.0       1774
# 9         140            NaN         205          RFn       1939.0       1077
# 10        134            NaN         384          Unf       1965.0       1040
# 11        177            NaN         736          Fin       2005.0       2324
# 12        175            NaN         352          NaN       1962.0        912
# 13       1494            NaN         840          RFn       2006.0       1494
# 14        520            NaN         352          RFn       1960.0       1253
# 15        832            NaN         576          Unf       1991.0        854
# 16        426            NaN         480          Fin       1970.0       1004
# 17          0            NaN         516          Unf       1967.0       1296
# 18        468            NaN         576          Unf       2004.0       1114
# 19        525            NaN         294          Unf       1958.0       1339
# 20       1158            NaN         853          RFn       2005.0       2376
# 21        637            NaN         280          Unf       1930.0       1108
# 22       1777            NaN         534          RFn       2002.0       1795
# 23        200            NaN         572          NaN       1976.0       1060
# 24        204            NaN         270          Unf       1968.0       1060
# 25       1566            NaN         890          RFn       2007.0       1600
# 26        180            NaN         576          Unf       2005.0        900
# 27        486            NaN         772          NaN       2008.0       1704
# 28        207            0.0         319          RFn       1957.0       1600
# 29        520            NaN         240          Unf       1920.0        520
# 30        649            NaN         250          Unf       1920.0       1317
# 31       1228            NaN         271          Unf       1966.0       1228
# 32       1234            0.0         484          RFn       2007.0       1234
# 33        380            NaN         447          RFn       1959.0       1700
# 34        408            NaN         556          Fin       2005.0       1561
# 35       1117            NaN         691          NaN       2004.0       2452
# 36       1097            NaN         672          Unf       1995.0       1097
# 37         84            0.0         498          Fin       1954.0       1297
# 38        326            NaN         246          Unf       1953.0       1057
# 39          0            NaN           0         None          NaN       1152
#
#    KitchenQual  LotArea  LotFrontage  MasVnrArea  OpenPorchSF  OverallCond  \
# 0           Gd     8450         65.0       196.0           61            5
# 1           TA     9600         80.0         0.0            0            8
# 2           Gd    11250         68.0       162.0           42            5
# 3           Gd     9550         60.0         0.0           35            5
# 4           Gd    14260         84.0       350.0           84            5
# 5           TA    14115         85.0         0.0           30            5
# 6           Gd    10084         75.0       186.0           57            5
# 7           TA    10382          NaN       240.0          204            6
# 8           TA     6120         51.0         0.0            0            5
# 9           TA     7420         50.0         0.0            4            6
# 10          TA    11200         70.0         0.0            0            5
# 11          Ex    11924         85.0       286.0           21            5
# 12          TA    12968          NaN         0.0            0            6
# 13          Gd    10652         91.0       306.0           33            5
# 14          TA    10920          NaN       212.0          213            5
# 15          TA     6120         51.0         0.0          112            8
# 16          TA    11241          NaN       180.0            0            7
# 17          TA    10791         72.0         0.0            0            5
# 18          Gd    13695         66.0         0.0          102            5
# 19          TA     7560         70.0         0.0            0            6
# 20          Gd    14215        101.0       380.0          154            5
# 21          Gd     7449         57.0         0.0            0            7
# 22          Gd     9742         75.0       281.0          159            5
# 23          TA     4224         44.0         0.0          110            7
# 24          Gd     8246          NaN         0.0           90            8
# 25          Gd    14230        110.0       640.0           56            5
# 26          Gd     7200         60.0         0.0           32            7
# 27          Gd    11478         98.0       200.0           50            5
# 28          TA    16321         47.0         0.0          258            6
# 29          Fa     6324         60.0         0.0            0            6
# 30          TA     8500         50.0         0.0           54            4
# 31          Gd     8544          NaN         0.0           65            6
# 32          Gd    11049         85.0         0.0           30            5
# 33          Gd    10552         70.0         0.0           38            5
# 34          Ex     7313         60.0       246.0           47            5
# 35          Gd    13418        108.0       132.0           32            5
# 36          TA    10859        112.0         0.0           64            5
# 37          TA     8532         74.0       650.0            0            6
# 38          Gd     7922         68.0         0.0           52            7
# 39          Fa     6040         65.0         0.0            0            5
#
#     OverallQual  TotalBsmtSF  WoodDeckSF  YearBuilt  YearRemodAdd  SalePrice
# 0             7          856         0.0       2003          2003     208500
# 1             6         1262         NaN       1976          1976     181500
# 2             7          920         NaN       2001          2002     223500
# 3             7          756         NaN       1915          1970     140000
# 4             8         1145         NaN       2000          2000     250000
# 5             5          796         NaN       1993          1995     143000
# 6             8         1686         NaN       2004          2005     307000
# 7             7         1107         NaN       1973          1973     200000
# 8             7          952         NaN       1931          1950     129900
# 9             5          991         NaN       1939          1950     118000
# 10            5         1040         NaN       1965          1965     129500
# 11            9         1175         NaN       2005          2006     345000
# 12            5          912         NaN       1962          1962     144000
# 13            7         1494       160.0       2006          2007     279500
# 14            6         1253         NaN       1960          1960     157000
# 15            7          832         NaN       1929          2001     132000
# 16            6         1004         NaN       1970          1970     149000
# 17            4            0         NaN       1967          1967      90000
# 18            5         1114         NaN       2004          2004     159000
# 19            5         1029         NaN       1958          1965     139000
# 20            8         1158       240.0       2005          2006     325300
# 21            7          637         NaN       1930          1950     139400
# 22            8         1777         NaN       2002          2002     230000
# 23            5         1040       100.0       1976          1976     129900
# 24            5         1060         NaN       1968          2001     154000
# 25            8         1566         NaN       2007          2007     256300
# 26            5          900         NaN       1951          2000     134800
# 27            8         1704         NaN       2007          2008     306000
# 28            5         1484         NaN       1957          1997     207500
# 29            4          520         NaN       1927          1950      68500
# 30            4          649         NaN       1920          1950      40000
# 31            5         1228         NaN       1966          2006     149350
# 32            8         1234         NaN       2007          2007     179900
# 33            5         1398         NaN       1959          1959     165500
# 34            9         1561       203.0       2005          2005     277500
# 35            8         1117         NaN       2004          2005     309000
# 36            5         1097         NaN       1994          1995     145000
# 37            5         1297         NaN       1954          1990     153000
# 38            5         1057         NaN       1953          2007     109000
# 39            4            0         NaN       1955          1955      82000

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as they support your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * If you do not need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)
