# %% [markdown]
# # **Data Collection Notebook**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save it as raw data.
# * Inspect data and save it under outputs/datasets/collection.
# * Assess the need for data cleaning based on inital inspection.
#
# ## Inputs
#
# * Kaggle JSON file - this is the authentication token required to access the Kaggle dataset.
#
# ## Outputs
#
# * Generate dataset: outputs/datasets/datacollection/house_prices_records.csv

# %% [markdown]
# ## Notebook in Relation to CRISP-DM
#
# This constitutes the data collection stage.

# %% [markdown]
# ## Kernel Selection
#
# Please use a Python 3.8.12 kernel to run this notebook. This application has been developed in a local workspace using Python 3.8.12. If you use a different version of Python to run this notebook, some of the required dependencies may not function correctly.

# %% [markdown]
# ---

# %% [markdown]
# ## Install Python Packages in the Notebooks

# %%
# %pip install -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt
# Out:
# Collecting altair==4.2.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 1))
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 7.0 MB/s eta 0:00:0000:0100:01
# Collecting astor==0.8.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 2))
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting asttokens==2.2.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 3))
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs==23.1.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 5)) (0.2.0)
# Collecting backports.zoneinfo==0.2.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 6))
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 12.8 MB/s eta 0:00:00
# Collecting base58==2.1.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 7))
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting blinker==1.6.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 8))
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting cachetools==5.3.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 9))
#   Obtaining dependency information for cachetools==5.3.1 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: certifi==2023.7.22 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 10)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.2.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 11)) (3.2.0)
# Collecting click==7.1.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 12))
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: comm==0.1.4 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 13)) (0.1.4)
# Collecting cycler==0.11.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 14))
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting dacite==1.8.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 15))
#   Obtaining dependency information for dacite==1.8.1 from https://files.pythonhosted.org/packages/21/0f/cf0943f4f55f0fbc7c6bd60caf1343061dff818b02af5a0d444e473bb78d/dacite-1.8.1-py3-none-any.whl.metadata
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting debugpy==1.6.7.post1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 16))
#   Obtaining dependency information for debugpy==1.6.7.post1 from https://files.pythonhosted.org/packages/3f/7c/1baf8e2899ea754ae6c2f17c3cf4d6cea9fbc2516ee1e785c105617da380/debugpy-1.6.7.post1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading debugpy-1.6.7.post1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: decorator==5.1.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 17)) (5.1.1)
# Collecting entrypoints==0.4 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 18))
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: executing==1.2.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 19)) (1.2.0)
# Collecting feature-engine==1.0.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 20))
#   Downloading feature_engine-1.0.2-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.5/152.5 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: gitdb==4.0.10 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 21)) (4.0.10)
# Collecting GitPython==3.1.32 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 22))
#   Obtaining dependency information for GitPython==3.1.32 from https://files.pythonhosted.org/packages/67/50/742c2fb60989b76ccf7302c7b1d9e26505d7054c24f08cc7ec187faaaea7/GitPython-3.1.32-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.32-py3-none-any.whl.metadata (10.0 kB)
# Collecting htmlmin==0.1.12 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 23))
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna==3.4 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 24)) (3.4)
# Collecting ImageHash==4.3.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 25))
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.8 MB/s eta 0:00:00
# Collecting imbalanced-learn==0.8.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 26))
#   Downloading imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata==6.8.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 27)) (6.8.0)
# Requirement already satisfied: importlib-resources==6.0.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 28)) (6.0.1)
# Collecting ipykernel==6.25.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 29))
#   Obtaining dependency information for ipykernel==6.25.1 from https://files.pythonhosted.org/packages/ca/ca/1089ddd8dd3ba03ea593bf20cdc2f7fe02526dcd7d966b7da47aa105e65b/ipykernel-6.25.1-py3-none-any.whl.metadata
#   Downloading ipykernel-6.25.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipython==8.12.2 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 30)) (8.12.2)
# Collecting ipywidgets==8.0.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 31))
#   Downloading ipywidgets-8.0.2-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.4/134.4 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: jedi==0.19.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 32)) (0.19.0)
# Collecting Jinja2==3.1.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 33))
#   Downloading Jinja2-3.1.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 32.9 MB/s eta 0:00:00
# Collecting joblib==1.3.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 34))
#   Obtaining dependency information for joblib==1.3.2 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: jsonschema==4.19.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 35)) (4.19.0)
# Requirement already satisfied: jsonschema-specifications==2023.7.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 36)) (2023.7.1)
# Collecting jupyter-client==8.3.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 37))
#   Obtaining dependency information for jupyter-client==8.3.0 from https://files.pythonhosted.org/packages/29/24/0491f7837cedf39ae0f96d9b3e4db2fae31cc4dd5eac00a98ab0db996c9b/jupyter_client-8.3.0-py3-none-any.whl.metadata
#   Downloading jupyter_client-8.3.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: jupyter-core==5.3.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 38)) (5.3.1)
# Collecting jupyterlab-widgets==3.0.8 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 39))
#   Obtaining dependency information for jupyterlab-widgets==3.0.8 from https://files.pythonhosted.org/packages/74/5e/2475ac62faf2e342b2bf20b8d8e375f49400ecb38f52e4e0a7557eb1cedb/jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata (4.1 kB)
# Collecting kiwisolver==1.4.4 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 40))
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.6 MB/s eta 0:00:00a 0:00:01
# Collecting MarkupSafe==2.0.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 41))
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting matplotlib==3.3.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 42))
#   Downloading matplotlib-3.3.1-cp38-cp38-manylinux1_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 33.5 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 43)) (0.1.6)
# Collecting multimethod==1.9.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 44))
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting nest-asyncio==1.5.7 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 45))
#   Obtaining dependency information for nest-asyncio==1.5.7 from https://files.pythonhosted.org/packages/7e/dd/69a7a6e89bb1fe09f99bde22027154c487b1e8b6769e642d7f56f35696d3/nest_asyncio-1.5.7-py3-none-any.whl.metadata
#   Downloading nest_asyncio-1.5.7-py3-none-any.whl.metadata (2.7 kB)
# Collecting networkx==3.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 46))
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.1 MB/s eta 0:00:00a 0:00:01
# Collecting numpy==1.18.5 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 47))
#   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 24.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging==23.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 48)) (23.1)
# Collecting pandas==1.4.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 49))
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 34.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: parso==0.8.3 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 50)) (0.8.3)
# Collecting patsy==0.5.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 51))
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: pexpect==4.8.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 52)) (4.8.0)
# Collecting phik==0.12.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 53))
#   Downloading phik-0.12.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 41.4 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare==0.7.5 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 54)) (0.7.5)
# Collecting Pillow==10.0.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 55))
#   Obtaining dependency information for Pillow==10.0.0 from https://files.pythonhosted.org/packages/ff/8c/5927a58c43ebc16e508eef325fdc6473b569e2474d3b4be49798aa371007/Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata
#   Downloading Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: pkgutil-resolve-name==1.3.10 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 56)) (1.3.10)
# Requirement already satisfied: platformdirs==3.10.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 57)) (3.10.0)
# Collecting plotly==4.12.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 58))
#   Downloading plotly-4.12.0-py2.py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 22.5 MB/s eta 0:00:0000:0100:01
# Collecting ppscore==1.2.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 59))
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prompt-toolkit==3.0.39 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 60)) (3.0.39)
# Collecting protobuf==3.20.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 61))
#   Downloading protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: psutil==5.9.5 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 62)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 63)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 64)) (0.2.2)
# Collecting pyarrow==12.0.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 65))
#   Obtaining dependency information for pyarrow==12.0.1 from https://files.pythonhosted.org/packages/e1/91/676b6ef5181fd0229ec35477eb94ff55fc5114ebab7a4669db311ddc9385/pyarrow-12.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pyarrow-12.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pydantic==1.10.12 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 66))
#   Obtaining dependency information for pydantic==1.10.12 from https://files.pythonhosted.org/packages/5d/68/7a0c5f8b854d3fad9cd82a6312205025597481e46b4ec36f6dea4f1fb93b/pydantic-1.10.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pydantic-1.10.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 19.3 MB/s eta 0:00:00
# Collecting pydeck==0.8.1b0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 67))
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 28.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pygments==2.16.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 68)) (2.16.1)
# Collecting pyparsing==3.1.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 69))
#   Obtaining dependency information for pyparsing==3.1.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 70)) (2.8.2)
# Collecting pytz==2023.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 71))
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 34.9 MB/s eta 0:00:00
# Collecting PyWavelets==1.4.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 72))
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 32.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML==6.0.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 73)) (6.0.1)
# Requirement already satisfied: pyzmq==25.1.1 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 74)) (25.1.1)
# Requirement already satisfied: referencing==0.30.2 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 75)) (0.30.2)
# Requirement already satisfied: requests==2.31.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 76)) (2.31.0)
# Collecting retrying==1.3.4 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 77))
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting rpds-py==0.9.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 78))
#   Obtaining dependency information for rpds-py==0.9.2 from https://files.pythonhosted.org/packages/7f/19/aa000240fa9343858a967b08037792695a66560ce5054528198190ce291b/rpds_py-0.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading rpds_py-0.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting scikit-learn==0.24.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 79))
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 26.9 MB/s eta 0:00:0000:0100:01
# Collecting scipy==1.9.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 80))
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 22.4 MB/s eta 0:00:0000:0100:01
# Collecting seaborn==0.11.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 81))
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.1/283.1 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 82)) (1.16.0)
# Collecting smmap==5.0.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 83))
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: stack-data==0.6.2 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 84)) (0.6.2)
# Collecting statsmodels==0.14.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 85))
#   Downloading statsmodels-0.14.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 33.8 MB/s eta 0:00:0000:010:01
# Collecting streamlit==0.85.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 86))
#   Downloading streamlit-0.85.0-py2.py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 39.0 MB/s eta 0:00:0000:0100:01
# Collecting tangled-up-in-unicode==0.2.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 87))
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 42.0 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl==3.2.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 88))
#   Obtaining dependency information for threadpoolctl==3.2.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting toml==0.10.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 89))
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting toolz==0.12.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 90))
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado==6.3.3 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 91)) (6.3.3)
# Collecting tqdm==4.66.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 92))
#   Obtaining dependency information for tqdm==4.66.1 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 9.4 MB/s eta 0:00:00
# Collecting traitlets==5.9.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 93))
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 28.6 MB/s eta 0:00:00
# Collecting typeguard==2.13.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 94))
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting typing-extensions==4.7.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 95))
#   Obtaining dependency information for typing-extensions==4.7.1 from https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting tzlocal==5.0.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 96))
#   Obtaining dependency information for tzlocal==5.0.1 from https://files.pythonhosted.org/packages/84/d2/730a87f0dbf184760394a85088d0d2366a5a8a32bc32ffd869a83f1de854/tzlocal-5.0.1-py3-none-any.whl.metadata
#   Downloading tzlocal-5.0.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: urllib3==2.0.4 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 97)) (2.0.4)
# Collecting validators==0.21.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 98))
#   Obtaining dependency information for validators==0.21.2 from https://files.pythonhosted.org/packages/8d/e7/c2d0758c58dbd463b4a0a650f8cf3af5c4cbb6fbc61a36ce077964286feb/validators-0.21.2-py3-none-any.whl.metadata
#   Downloading validators-0.21.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting visions==0.7.5 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 99))
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 20.1 MB/s eta 0:00:00
# Collecting watchdog==3.0.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 100))
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth==0.2.6 in /home/codeany/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 101)) (0.2.6)
# Collecting widgetsnbextension==4.0.8 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 102))
#   Obtaining dependency information for widgetsnbextension==4.0.8 from https://files.pythonhosted.org/packages/8e/d4/d31b12ac0b87e8cc9fdb6ea1eb6596de405eaaa2f25606aaa755d0eebbc0/widgetsnbextension-4.0.8-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl.metadata (1.6 kB)
# Collecting wordcloud==1.9.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 103))
#   Obtaining dependency information for wordcloud==1.9.2 from https://files.pythonhosted.org/packages/5d/6b/011c4470fde93e2bfbe4cc1012077f6b96030124e3cd069b5500ad6e8b69/wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting xgboost==1.2.1 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 104))
#   Downloading xgboost-1.2.1-py3-none-manylinux2010_x86_64.whl (148.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 MB 10.6 MB/s eta 0:00:0000:0100:01
# Collecting ydata-profiling==4.4.0 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 105))
#   Obtaining dependency information for ydata-profiling==4.4.0 from https://files.pythonhosted.org/packages/4b/90/04630cea435fef54d48b0979f1a25b75e541a8140e4e3c63cfda1b00ec7f/ydata_profiling-4.4.0-py2.py3-none-any.whl.metadata
#   Downloading ydata_profiling-4.4.0-py2.py3-none-any.whl.metadata (20 kB)
# Collecting yellowbrick==1.3 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 106))
#   Downloading yellowbrick-1.3-py3-none-any.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.3/271.3 kB 51.0 MB/s eta 0:00:00
# Collecting zipp==3.16.2 (from -r /workspaces/CI-PP5-Peter-Regan-Heritage-Housing-Project/requirements.txt (line 107))
#   Obtaining dependency information for zipp==3.16.2 from https://files.pythonhosted.org/packages/8c/08/d3006317aefe25ea79d3b76c9650afabaf6d63d1c8443b236e7405447503/zipp-3.16.2-py3-none-any.whl.metadata
#   Downloading zipp-3.16.2-py3-none-any.whl.metadata (3.7 kB)
# Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading debugpy-1.6.7.post1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.6 MB/s eta 0:00:00a 0:00:01
# Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 27.7 MB/s eta 0:00:00
# Downloading ipykernel-6.25.1-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.0/154.0 kB 30.5 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 50.0 MB/s eta 0:00:00
# Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 23.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 36.3 MB/s eta 0:00:00
# Downloading nest_asyncio-1.5.7-py3-none-any.whl (5.3 kB)
# Downloading Pillow-10.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 37.6 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-12.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 23.6 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-1.10.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 49.1 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 21.6 MB/s eta 0:00:00
# Downloading rpds_py-0.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Downloading tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Downloading validators-0.21.2-py3-none-any.whl (25 kB)
# Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.5 MB/s eta 0:00:00a 0:00:01
# Downloading wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.3/461.3 kB 34.9 MB/s eta 0:00:00
# Downloading ydata_profiling-4.4.0-py2.py3-none-any.whl (356 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 54.1 MB/s eta 0:00:00
# Downloading zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Building wheels for collected packages: htmlmin, ppscore
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=4a57ff86b1c988cd26be08af4331ddf4fea251735138211f3b2d6f427b1b0846
#   Stored in directory: /home/codeany/.cache/pip/wheels/23/14/6e/4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
#   Building wheel for ppscore (setup.py) ... done
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13064 sha256=40f90ef5c8ed27198cd0f5b3acde822a82c4bbc226318cfe5bc5b2c4e996a944
#   Stored in directory: /home/codeany/.cache/pip/wheels/fb/0e/65/da65ce669381fc01b6ef990d301d3586991f89bff1175877a4
# Successfully built htmlmin ppscore
# Installing collected packages: pytz, htmlmin, zipp, widgetsnbextension, watchdog, validators, typing-extensions, typeguard, traitlets, tqdm, toolz, toml, threadpoolctl, tangled-up-in-unicode, smmap, rpds-py, retrying, pyparsing, protobuf, Pillow, numpy, networkx, nest-asyncio, multimethod, MarkupSafe, kiwisolver, jupyterlab-widgets, joblib, entrypoints, debugpy, dacite, cycler, click, cachetools, blinker, base58, backports.zoneinfo, asttokens, astor, tzlocal, scipy, PyWavelets, pydantic, pyarrow, plotly, patsy, pandas, matplotlib, Jinja2, xgboost, wordcloud, visions, statsmodels, seaborn, scikit-learn, pydeck, phik, jupyter-client, ImageHash, GitPython, yellowbrick, ppscore, ipykernel, imbalanced-learn, feature-engine, ydata-profiling, ipywidgets, altair, streamlit

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/CI-PP5-Peter-Regan-Heritage-Housing-Project'

# %% [markdown]
# # Fetch Data from Kaggle

# %% [markdown]
# Install Kaggle package to collect data from Kaggle.

# %%
# %pip install kaggle==1.5.12
# Out:
# Requirement already satisfied: kaggle==1.5.12 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (1.16.0)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2023.7.22)
# Requirement already satisfied: python-dateutil in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.8.2)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.31.0)
# Requirement already satisfied: tqdm in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (4.66.1)
# Requirement already satisfied: python-slugify in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (8.0.1)
# Requirement already satisfied: urllib3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from kaggle==1.5.12) (2.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from python-slugify->kaggle==1.5.12) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests->kaggle==1.5.12) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests->kaggle==1.5.12) (3.4)
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You will need a Kaggle token to fetch the data required to run these notebooks. If you do not already have a Kaggle token, follow these steps:
#
# 1. Visit www.kaggle.com and register an account.
#
# 2. When you have finished registering your account, log in.
#
# 3. Click on your profile/account avatar that will be visible at the top right hand corner of the browser window.
#
# 4. Scroll down to the "API" section.
#
# 5. Click on "Create New Token". This will automatically create your kaggle token which will be in the form of a json
#    file.
#
# 6. Depending on your browser, this kaggle.json file should download automatically.
#
# 7. Download the kaggle.json file manually if this is not the case.

# %% [markdown]
# # Make Kaggle Token Available in Your Coding Environment
#
# Once your Kaggle token has been downloaded, you can manually click, hold and drag it from your Downloads folder on your device (or wherever else you may have chosen to store it) into the file directory of your coding environment.

# %% [markdown]
# After you have put your Kaggle token in your coding environment's file directory, run the cell below so that it is recognised within the session.

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %% [markdown]
# Get the dataset path from its Kaggle URL. For this application, use the dataset from this url: https://www.kaggle.com/datasets/codeinstitute/housing-prices-data

# %% [markdown]
# Run the following cell to define the Kaggle dataset within the context of your environment and session, set its destination folder and download it.

# %%
KaggleDatasetPath = "codeinstitute/housing-prices-data"
DestinationFolder = "inputs/datasets/raw"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# Downloading housing-prices-data.zip to inputs/datasets/raw
#   0%|                                               | 0.00/49.6k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 49.6k/49.6k [00:00<00:00, 2.35MB/s]

# %% [markdown]
# Run the following cell to unzip the downloaded file, delete the zip file and delete the kaggle.json file.

# %%
! unzip {DestinationFolder}/*.zip -d {DestinationFolder} \
  && rm {DestinationFolder}/*.zip \
  && rm kaggle.json
# Out:
# Archive:  inputs/datasets/raw/housing-prices-data.zip
#   inflating: inputs/datasets/raw/house-metadata.txt
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv
#   inflating: inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/inherited_houses.csv

# %% [markdown]
# ---

# %% [markdown]
# # Load and Inspect Kaggle Data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(f"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")
pd.set_option('display.max_columns', None)
df.head(40)
# Out:
#     1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0        856     854.0           3.0           No         706          GLQ
# 1       1262       0.0           3.0           Gd         978          ALQ
# 2        920     866.0           3.0           Mn         486          GLQ
# 3        961       NaN           NaN           No         216          ALQ
# 4       1145       NaN           4.0           Av         655          GLQ
# 5        796     566.0           1.0           No         732          GLQ
# 6       1694       0.0           3.0           Av        1369          GLQ
# 7       1107     983.0           3.0           Mn         859          ALQ
# 8       1022     752.0           2.0           No           0          Unf
# 9       1077       0.0           2.0           No         851          GLQ
# 10      1040       0.0           3.0           No         906          Rec
# 11      1182    1142.0           4.0           No         998          NaN
# 12       912       0.0           2.0           No         737          ALQ
# 13      1494       0.0           3.0           Av           0          Unf
# 14      1253       0.0           NaN           No         733          BLQ
# 15       854       0.0           2.0           No           0          Unf
# 16      1004       0.0           2.0           No         578          ALQ
# 17      1296       0.0           2.0         None           0         None
# 18      1114       NaN           NaN           No         646          GLQ
# 19      1339       0.0           3.0           No         504          LwQ
# 20      1158    1218.0           4.0           Av           0          Unf
# 21      1108       0.0           3.0           No           0          Unf
# 22      1795       0.0           3.0           No           0          NaN
# 23      1060       0.0           3.0           No         840          GLQ
# 24      1060       0.0           3.0           Mn         188          Rec
# 25      1600       0.0           3.0           No           0          Unf
# 26       900       0.0           3.0           Mn         234          NaN
# 27      1704       NaN           3.0           No        1218          GLQ
# 28      1600       0.0           2.0           Gd        1277          BLQ
# 29       520       0.0           1.0           No           0          Unf
# 30       649     668.0           3.0           No           0          Unf
# 31      1228       0.0           3.0           No           0          Unf
# 32      1234       0.0           3.0           Av           0          Unf
# 33      1700       0.0           4.0           No        1018          Rec
# 34      1561       0.0           2.0           No        1153          GLQ
# 35      1132    1320.0           4.0           Av           0          Unf
# 36      1097       0.0           3.0           No           0          Unf
# 37      1297       0.0           NaN           No        1213          Rec
# 38      1057       0.0           3.0           No         731          GLQ
# 39      1152       0.0           NaN         None           0         None
#
#     BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  GarageYrBlt  GrLivArea  \
# 0         150            0.0         548          RFn       2003.0       1710
# 1         284            NaN         460          RFn       1976.0       1262
# 2         434            0.0         608          RFn       2001.0       1786
# 3         540            NaN         642          Unf       1998.0       1717
# 4         490            0.0         836          RFn       2000.0       2198
# 5          64            NaN         480          Unf       1993.0       1362
# 6         317            NaN         636          RFn       2004.0       1694
# 7         216            NaN         484          NaN       1973.0       2090
# 8         952            NaN         468          Unf       1931.0       1774
# 9         140            NaN         205          RFn       1939.0       1077
# 10        134            NaN         384          Unf       1965.0       1040
# 11        177            NaN         736          Fin       2005.0       2324
# 12        175            NaN         352          NaN       1962.0        912
# 13       1494            NaN         840          RFn       2006.0       1494
# 14        520            NaN         352          RFn       1960.0       1253
# 15        832            NaN         576          Unf       1991.0        854
# 16        426            NaN         480          Fin       1970.0       1004
# 17          0            NaN         516          Unf       1967.0       1296
# 18        468            NaN         576          Unf       2004.0       1114
# 19        525            NaN         294          Unf       1958.0       1339
# 20       1158            NaN         853          RFn       2005.0       2376
# 21        637            NaN         280          Unf       1930.0       1108
# 22       1777            NaN         534          RFn       2002.0       1795
# 23        200            NaN         572          NaN       1976.0       1060
# 24        204            NaN         270          Unf       1968.0       1060
# 25       1566            NaN         890          RFn       2007.0       1600
# 26        180            NaN         576          Unf       2005.0        900
# 27        486            NaN         772          NaN       2008.0       1704
# 28        207            0.0         319          RFn       1957.0       1600
# 29        520            NaN         240          Unf       1920.0        520
# 30        649            NaN         250          Unf       1920.0       1317
# 31       1228            NaN         271          Unf       1966.0       1228
# 32       1234            0.0         484          RFn       2007.0       1234
# 33        380            NaN         447          RFn       1959.0       1700
# 34        408            NaN         556          Fin       2005.0       1561
# 35       1117            NaN         691          NaN       2004.0       2452
# 36       1097            NaN         672          Unf       1995.0       1097
# 37         84            0.0         498          Fin       1954.0       1297
# 38        326            NaN         246          Unf       1953.0       1057
# 39          0            NaN           0         None          NaN       1152
#
#    KitchenQual  LotArea  LotFrontage  MasVnrArea  OpenPorchSF  OverallCond  \
# 0           Gd     8450         65.0       196.0           61            5
# 1           TA     9600         80.0         0.0            0            8
# 2           Gd    11250         68.0       162.0           42            5
# 3           Gd     9550         60.0         0.0           35            5
# 4           Gd    14260         84.0       350.0           84            5
# 5           TA    14115         85.0         0.0           30            5
# 6           Gd    10084         75.0       186.0           57            5
# 7           TA    10382          NaN       240.0          204            6
# 8           TA     6120         51.0         0.0            0            5
# 9           TA     7420         50.0         0.0            4            6
# 10          TA    11200         70.0         0.0            0            5
# 11          Ex    11924         85.0       286.0           21            5
# 12          TA    12968          NaN         0.0            0            6
# 13          Gd    10652         91.0       306.0           33            5
# 14          TA    10920          NaN       212.0          213            5
# 15          TA     6120         51.0         0.0          112            8
# 16          TA    11241          NaN       180.0            0            7
# 17          TA    10791         72.0         0.0            0            5
# 18          Gd    13695         66.0         0.0          102            5
# 19          TA     7560         70.0         0.0            0            6
# 20          Gd    14215        101.0       380.0          154            5
# 21          Gd     7449         57.0         0.0            0            7
# 22          Gd     9742         75.0       281.0          159            5
# 23          TA     4224         44.0         0.0          110            7
# 24          Gd     8246          NaN         0.0           90            8
# 25          Gd    14230        110.0       640.0           56            5
# 26          Gd     7200         60.0         0.0           32            7
# 27          Gd    11478         98.0       200.0           50            5
# 28          TA    16321         47.0         0.0          258            6
# 29          Fa     6324         60.0         0.0            0            6
# 30          TA     8500         50.0         0.0           54            4
# 31          Gd     8544          NaN         0.0           65            6
# 32          Gd    11049         85.0         0.0           30            5
# 33          Gd    10552         70.0         0.0           38            5
# 34          Ex     7313         60.0       246.0           47            5
# 35          Gd    13418        108.0       132.0           32            5
# 36          TA    10859        112.0         0.0           64            5
# 37          TA     8532         74.0       650.0            0            6
# 38          Gd     7922         68.0         0.0           52            7
# 39          Fa     6040         65.0         0.0            0            5
#
#     OverallQual  TotalBsmtSF  WoodDeckSF  YearBuilt  YearRemodAdd  SalePrice
# 0             7          856         0.0       2003          2003     208500
# 1             6         1262         NaN       1976          1976     181500
# 2             7          920         NaN       2001          2002     223500
# 3             7          756         NaN       1915          1970     140000
# 4             8         1145         NaN       2000          2000     250000
# 5             5          796         NaN       1993          1995     143000
# 6             8         1686         NaN       2004          2005     307000
# 7             7         1107         NaN       1973          1973     200000
# 8             7          952         NaN       1931          1950     129900
# 9             5          991         NaN       1939          1950     118000
# 10            5         1040         NaN       1965          1965     129500
# 11            9         1175         NaN       2005          2006     345000
# 12            5          912         NaN       1962          1962     144000
# 13            7         1494       160.0       2006          2007     279500
# 14            6         1253         NaN       1960          1960     157000
# 15            7          832         NaN       1929          2001     132000
# 16            6         1004         NaN       1970          1970     149000
# 17            4            0         NaN       1967          1967      90000
# 18            5         1114         NaN       2004          2004     159000
# 19            5         1029         NaN       1958          1965     139000
# 20            8         1158       240.0       2005          2006     325300
# 21            7          637         NaN       1930          1950     139400
# 22            8         1777         NaN       2002          2002     230000
# 23            5         1040       100.0       1976          1976     129900
# 24            5         1060         NaN       1968          2001     154000
# 25            8         1566         NaN       2007          2007     256300
# 26            5          900         NaN       1951          2000     134800
# 27            8         1704         NaN       2007          2008     306000
# 28            5         1484         NaN       1957          1997     207500
# 29            4          520         NaN       1927          1950      68500
# 30            4          649         NaN       1920          1950      40000
# 31            5         1228         NaN       1966          2006     149350
# 32            8         1234         NaN       2007          2007     179900
# 33            5         1398         NaN       1959          1959     165500
# 34            9         1561       203.0       2005          2005     277500
# 35            8         1117         NaN       2004          2005     309000
# 36            5         1097         NaN       1994          1995     145000
# 37            5         1297         NaN       1954          1990     153000
# 38            5         1057         NaN       1953          2007     109000
# 39            4            0         NaN       1955          1955      82000

# %% [markdown]
# Generate dataframe summary.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1374 non-null   float64
#  2   BedroomAbvGr   1361 non-null   float64
#  3   BsmtExposure   1460 non-null   object
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinType1   1346 non-null   object
#  6   BsmtUnfSF      1460 non-null   int64
#  7   EnclosedPorch  136 non-null    float64
#  8   GarageArea     1460 non-null   int64
#  9   GarageFinish   1298 non-null   object
#  10  GarageYrBlt    1379 non-null   float64
#  11  GrLivArea      1460 non-null   int64
#  12  KitchenQual    1460 non-null   object
#  13  LotArea        1460 non-null   int64
#  14  LotFrontage    1201 non-null   float64
#  15  MasVnrArea     1452 non-null   float64
#  16  OpenPorchSF    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  OverallQual    1460 non-null   int64
#  19  TotalBsmtSF    1460 non-null   int64
#  20  WoodDeckSF     155 non-null    float64
#  21  YearBuilt      1460 non-null   int64
#  22  YearRemodAdd   1460 non-null   int64
#  23  SalePrice      1460 non-null   int64
# dtypes: float64(7), int64(13), object(4)
# memory usage: 273.9+ KB

# %% [markdown]
# Check the dataset for missing values.

# %%
df.isnull().sum()
# Out:
# 1stFlrSF            0
# 2ndFlrSF           86
# BedroomAbvGr       99
# BsmtExposure        0
# BsmtFinSF1          0
# BsmtFinType1      114
# BsmtUnfSF           0
# EnclosedPorch    1324
# GarageArea          0
# GarageFinish      162
# GarageYrBlt        81
# GrLivArea           0
# KitchenQual         0
# LotArea             0
# LotFrontage       259
# MasVnrArea          8
# OpenPorchSF         0
# OverallCond         0
# OverallQual         0
# TotalBsmtSF         0
# WoodDeckSF       1305
# YearBuilt           0
# YearRemodAdd        0
# SalePrice           0
# dtype: int64

# %% [markdown]
# We notice here that columns with missing values may be due to the fact that these features may not be applicable to all properties in the dataset.

# %% [markdown]
# Check for data entries that have been duplicated.

# %%
df[df.duplicated(subset=None)]
# Out:
# Empty DataFrame
# Columns: [1stFlrSF, 2ndFlrSF, BedroomAbvGr, BsmtExposure, BsmtFinSF1, BsmtFinType1, BsmtUnfSF, EnclosedPorch, GarageArea, GarageFinish, GarageYrBlt, GrLivArea, KitchenQual, LotArea, LotFrontage, MasVnrArea, OpenPorchSF, OverallCond, OverallQual, TotalBsmtSF, WoodDeckSF, YearBuilt, YearRemodAdd, SalePrice]
# Index: []

# %% [markdown]
# Check for unique values in columns that have non-numerical data values as these are likely to contain categorical data.

# %%
for col in df:
    if df[col].dtypes=='object':
        print(col, '-', df[col].unique())
# Out:
# BsmtExposure - ['No' 'Gd' 'Mn' 'Av' 'None']
# BsmtFinType1 - ['GLQ' 'ALQ' 'Unf' 'Rec' nan 'BLQ' 'None' 'LwQ']
# GarageFinish - ['RFn' 'Unf' nan 'Fin' 'None']
# KitchenQual - ['Gd' 'TA' 'Ex' 'Fa']

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# Save the data file in a local folder named 'datacollection' under 'outputs/datasets/' and push to repository.

# %%
import os
try:
  os.makedirs(name='outputs/datasets/datacollection') # create a folder for the data output
except Exception as e:
  print(e)

df.to_csv(f"outputs/datasets/datacollection/house_prices_records.csv",index=False)
